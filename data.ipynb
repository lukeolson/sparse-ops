# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
files =\
['data-pybind-omp-1.npy',
'data-pybind-omp-2.npy',
'data-pybind-omp-3.npy',
'data-pybind-omp-4.npy',
'data-pybind.npy',
'data-scipy.npy']
df = pd.DataFrame()
for f in files:
    test = f.split('.')[0][5:]
    data = np.load(f)
    df = df.append(pd.DataFrame({'times': data,
                                 'run': np.arange(len(data)),
                                 'test': test}))

# %%
g = sns.lmplot(x="run", y="times", hue="test",
               data=df, size=10)
ax = plt.gca()
ax.set_yscale('log')
