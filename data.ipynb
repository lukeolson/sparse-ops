# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
files =\
['data-pybind-omp-{}.npy'.format(i) for i in range(1,25)]+\
['data-pybind.npy',
'data-scipy.npy']
df = pd.DataFrame()
for f in files:
    test = f.split('.')[0][5:]
    data = np.load(f)
    df = df.append(pd.DataFrame({'times': data,
                                 'run': np.arange(len(data)),
                                 'test': test}))

# %%
g = sns.lmplot(x="run", y="times", hue="test",
               data=df, size=10)
ax = plt.gca()
ax.set_yscale('log')

# %%
g = sns.factorplot(x="test", y="times", data=df,
                   size=10, kind="lv")
ax = plt.gca()
fig = plt.gcf()
fig.autofmt_xdate()
ax.set_yscale('log')
